# %%
#IMPORTS

import pandas as pd
import numpy as np

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.common.exceptions import NoSuchElementException

import requests

from bs4 import BeautifulSoup
import time

# %%
df1 = pd.read_csv('/Users/javm/Desktop/Projects/Sistema-Recomendacion-Libros/books_1.csv')
df2 = pd.read_csv('/Users/javm/Desktop/Projects/Sistema-Recomendacion-Libros/books_2.csv')
df3 = pd.read_csv('/Users/javm/Desktop/Projects/Sistema-Recomendacion-Libros/books_3.csv')

# %%
libros = pd.concat([df1,df2,df3])
libros.to_csv('libros.csv', index = False )

# %%
libros_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 299
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      1000 non-null   object
#  1   authors    1000 non-null   object
#  2   publisher  1000 non-null   object
#  3   blurb      982 non-null    object
# dtypes: object(4)
# memory usage: 39.1+ KB

# %%
libros_df.dropna(inplace = True)
libros_df
# Out:
#                                                  title  \
# 0    Generación idiota: Una crítica al adolescentrismo
# 1                                  Spare: En la sombra
# 2    Volver a empezar / It Starts with Us (Spanish ...
# 3    ¡Vámonos a la Estufa! con Janet Jauja Cocina M...
# 4      RUGE: O espera a ser devorado (Spanish Edition)
# ..                                                 ...
# 294           EL DR. SILKWORTH EN ALCOHÓLICOS ANÓNIMOS
# 295  La Inspiración de Rumi: 100 Citas Para Elevar ...
# 296  El Derecho como objeto de investigación: Enfoq...
# 297  Reflexiones jurídicas sobre la Jurisdicción Es...
# 299  El arte de no encajar: Lo que pasa cuando el a...
#
#                                       authors  \
# 0                        ['', 'Agustin Laje']
# 1    ['', 'Prince Harry, The Duke of Sussex']
# 2                      ['', 'Colleen Hoover']
# 3                      ['', 'Kushner, Janet']
# 4                        ['', 'Daniel Habif']
# ..                                        ...
# 294  ['', '', 'Oslos Molina', 'Oslos Molina']
# 295                       ['', 'David Smith']
# 296                  ['', 'Elmer Arce Ortíz']
# 297              ['', 'Jaime Bernal Cuéllar']
# 299       ['', 'Noemí Navarro (@noemimisma)']
#
#                                        publisher  \
# 0                           HarperCollins Mexico
# 1                            PRH Grupo Editorial
# 2                 Planeta Publishing Corporation
# 3                                       Larousse
# 4        Editorial Planeta Mexicana S.A. de C.V.
# ..                                           ...
# 294                              Experiencias AA
# 295                      Independently published
# 296                            Palestra Editores
# 297                        Universidad Externado
# 299  Penguin Random House Grupo Editorial España
#
#                                                  blurb
# 0    Overview\nNotes From Your Bookseller\nEl contr...
# 1    Overview\nNotes From Your Bookseller\nLa contr...
# 2    Overview\nNotes From Your Bookseller\n¡Colleen...
# 3    Overview\nNotes From Your Bookseller\nJauja, l...
# 4    Overview\nNotes From Your Bookseller\nCon su c...
# ..                                                 ...
# 294  Overview\nBill decía frecuentemente que el pro...
# 295  Overview\nEn este libro, te sumergirás en la s...
# 296  Overview\nEste libro es una presentación de la...
# 297  Overview\nEl libro Reflexiones jurídicas sobre...
# 299  Overview\nEl libro testimonial de @Noemimisma\...
#
# [982 rows x 4 columns]
